# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
credit_card_data = pd.read_csv('/content/creditcard_2023.csv')

# %%
credit_card_data.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 568625 -0.370393  0.189694 -0.938153  ...  0.167503  0.419731  1.288249
# 568626 -0.016935 -0.147733  0.483894  ...  0.031874  0.388161 -0.154257
# 568627 -0.070958 -0.019997 -0.122048  ...  0.140788  0.536523 -0.211100
# 568628  0.580568 -0.207723  0.893527  ... -0.060381 -0.195609 -0.175488
# 568629 -0.347613 -0.340814  0.253971  ...  0.534853 -0.291514  0.157303
#
#              V24       V25       V26       V27       V28    Amount  Class
# 568625 -0.900861  0.560661 -0.006018  3.308968  0.081564   4394.16      1
# 568626 -0.846452 -0.153443  1.961398 -1.528642  1.704306   4653.40      1
# 568627 -0.448909  0.540073 -0.755836 -0.487540 -0.268741  23572.85      1
# 568628 -0.554643 -0.099669 -1.434931 -0.159269 -0.076251  10160.83      1
# 568629  0.931030 -0.349423 -1.090974 -1.575113  0.722936  21493.92      1
#
# [5 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
#  20  V20     568630 non-null  float64
#  21  V21     568630 non-null  float64
#  22  V22     568630 non-null  float64
#  23  V23     568630 non-null  float64
#  24  V24     568630 non-null  float64
#  25  V25     568630 non-null  float64
#  26  V26     568630 non-null  float64
#  27  V27     568630 non-null  float64
#  28  V28     568630 non-null  float64
#  29  Amount  568630 non-null  float64
#  30  Class   568630 non-null  int64
# dtypes: float64(29), int64(2)
# memory usage: 134.5 MB

# %%
credit_card_data.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
credit_card_data = credit_card_data.dropna(how='any')

# %%
credit_card_data.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
Real = credit_card_data[credit_card_data.Class == 0]
Fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(Real.shape)
print(Fraud.shape)
# Out:
# (284315, 31)
# (284315, 31)

# %%
Real.Amount.describe()
# Out:
# count    284315.000000
# mean      12026.313506
# std        6929.500715
# min          50.120000
# 25%        6034.540000
# 50%       11996.900000
# 75%       18040.265000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
Fraud.Amount.describe()
# Out:
# count    284315.000000
# mean      12057.601763
# std        6909.750891
# min          50.010000
# 25%        6074.640000
# 50%       12062.450000
# 75%       18033.780000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                   id        V1        V2        V3        V4        V5  \
# Class
# 0      142442.987714  0.505761 -0.491878  0.682095 -0.735981  0.338639
# 1      426186.012286 -0.505761  0.491878 -0.682095  0.735981 -0.338639
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.435088  0.491234 -0.144294  0.585522  ... -0.179851 -0.10964
# 1     -0.435088 -0.491234  0.144294 -0.585522  ...  0.179851  0.10964
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.014098 -0.010255  0.130107 -0.061847 -0.071052 -0.214002 -0.102024
# 1      0.014098  0.010255 -0.130107  0.061847  0.071052  0.214002  0.102024
#
#              Amount
# Class
# 0      12026.313506
# 1      12057.601763
#
# [2 rows x 30 columns]

# %% [markdown]
# Under_Sampling

# %%
#Real_sample = Real.sample(n = 500)
#Fraud_sample = Fraud.sample(n = 500)

# %% [markdown]
# Concatenate

# %%
#New_Dataset = pd.concat([Real_sample, Fraud_sample],axis = 0)

# %%
#New_Dataset.head()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 27874    27874  0.050460 -0.152242  1.184621 -0.680207  0.276807  0.167649
# 55102    55102  0.984612 -0.464524  0.965907 -0.235952  0.146255  0.914476
# 264515  264515  1.917608 -0.407577 -0.213477 -0.564944  0.740772  0.071429
# 236148  236148  0.264728 -0.366123  0.460797 -1.923970  0.416401  0.164504
# 191687  191687  1.640760 -0.512754  0.240094 -0.126320  0.324547  0.878684
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 27874   0.601230 -0.102489  0.320093  ... -0.208914 -0.753887 -0.070495
# 55102   0.238498 -0.091109  0.886823  ... -0.134629 -0.053372 -0.195318
# 264515  0.689220 -0.246484  0.563495  ... -0.079856  0.318395 -0.105425
# 236148  0.666118 -0.263711 -0.153454  ...  0.111322  1.533091 -0.278040
# 191687  0.318148 -0.101818  1.061697  ... -0.304498 -1.041482  0.386594
#
#              V24       V25       V26       V27       V28    Amount  Class
# 27874  -0.173306 -0.435917  0.200614  0.034184  0.093139   6972.73      0
# 55102  -1.357037  0.864062 -0.857509 -0.154216 -0.056636  17968.16      0
# 264515  0.277357  0.742164  1.490962 -0.362504 -0.305060   9590.19      0
# 236148  1.848759 -0.166266 -0.289716 -0.820748 -0.681113   7776.73      0
# 191687  0.336654 -0.507581 -3.068081 -0.178888 -0.185680  14937.80      0
#
# [5 rows x 31 columns]

# %%
#New_Dataset.tail()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 442013  442013 -0.482514  0.654223 -0.980648  0.605835 -0.569408 -0.230322
# 362635  362635  0.985065 -0.055313  0.271792  0.443231  0.509134 -0.110267
# 334043  334043 -0.242317  0.151858 -0.528623 -0.100015  0.187552  0.079166
# 519205  519205 -0.889033 -0.189479 -0.736514  0.943820 -0.026626 -1.312199
# 303005  303005 -0.473091  0.510145 -0.084713 -0.169373  0.422186  1.387411
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 442013 -0.213975 -0.105036 -0.595464  ...  0.090731  0.947341  0.024474
# 362635  0.549912 -0.201919  0.831898  ... -0.269375 -0.845591 -0.094638
# 334043 -0.207039  0.142638 -0.639146  ...  0.315684  1.144611 -0.260766
# 519205 -1.060424  0.326636 -0.857553  ...  0.314876  0.114877 -1.074793
# 303005 -0.221865 -1.843794  2.756632  ...  2.809211 -1.735640  1.334430
#
#              V24       V25       V26       V27       V28    Amount  Class
# 442013 -0.143965 -0.630332 -0.969543  0.445998 -0.387212   7401.52      1
# 362635 -0.054336  0.833520 -0.084713 -0.260601  0.064972   7272.91      1
# 334043 -0.367150  0.282980  1.574560  0.552865  0.401054    286.43      1
# 519205 -0.788937 -0.637616 -0.295104  2.309219  0.974557  15271.58      1
# 303005 -0.493134 -1.512477 -1.411553 -0.342728 -0.361132   9581.79      1
#
# [5 rows x 31 columns]

# %%
#New_Dataset['Class'].value_counts()
# Out:
# Class
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
#New_Dataset.groupby('Class').mean()
# Out:
#                id        V1        V2        V3        V4        V5        V6  \
# Class
# 0      137910.666  0.424984 -0.465916  0.694467 -0.752165  0.308166  0.416097
# 1      418952.188 -0.512032  0.460729 -0.651016  0.721161 -0.338383 -0.367753
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0      0.481802 -0.115275  0.643368  ... -0.227148 -0.119183  0.002085
# 1     -0.481153  0.143639 -0.555100  ...  0.082932  0.139205  0.057902
#
#             V23       V24       V25       V26       V27       V28       Amount
# Class
# 0     -0.061127  0.139799 -0.065659 -0.055723 -0.172439 -0.106978  11620.45424
# 1      0.042390 -0.166974 -0.036358  0.073565  0.229086  0.116816  12408.64996
#
# [2 rows x 30 columns]

# %% [markdown]
# Data Split

# %%
X = credit_card_data.drop (columns ='Class', axis = 1)
Y = credit_card_data['Class']

# %%
print(X)
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 0       0.519014 -0.130006  0.727159  ...  0.091202 -0.110552  0.217606
# 1       0.406466 -0.133118  0.347452  ... -0.233984 -0.194936 -0.605761
# 2       0.743511 -0.095576 -0.261297  ...  0.361652 -0.005020  0.702906
# 3       0.518269 -0.065130 -0.205698  ... -0.378223 -0.146927 -0.038212
# 4       0.658849 -0.212660  1.049921  ...  0.247237 -0.106984  0.729727
# ...          ...       ...       ...  ...       ...       ...       ...
# 568625 -0.370393  0.189694 -0.938153  ... -0.751011  0.167503  0.419731
# 568626 -0.016935 -0.147733  0.483894  ... -0.550260  0.031874  0.388161
# 568627 -0.070958 -0.019997 -0.122048  ... -0.076417  0.140788  0.536523
# 568628  0.580568 -0.207723  0.893527  ...  0.288186 -0.060381 -0.195609
# 568629 -0.347613 -0.340814  0.253971  ... -0.621378  0.534853 -0.291514
#
#              V23       V24       V25       V26       V27       V28    Amount
# 0      -0.134794  0.165959  0.126280 -0.434824 -0.081230 -0.151045  17982.10
# 1       0.079469 -0.577395  0.190090  0.296503 -0.248052 -0.064512   6531.37
# 2       0.945045 -1.154666 -0.605564 -0.312895 -0.300258 -0.244718   2513.54
# 3      -0.214048 -1.893131  1.003963 -0.515950 -0.165316  0.048424   5384.44
# 4      -0.161666  0.312561 -0.414116  1.071126  0.023712  0.419117  14278.97
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625  1.288249 -0.900861  0.560661 -0.006018  3.308968  0.081564   4394.16
# 568626 -0.154257 -0.846452 -0.153443  1.961398 -1.528642  1.704306   4653.40
# 568627 -0.211100 -0.448909  0.540073 -0.755836 -0.487540 -0.268741  23572.85
# 568628 -0.175488 -0.554643 -0.099669 -1.434931 -0.159269 -0.076251  10160.83
# 568629  0.157303  0.931030 -0.349423 -1.090974 -1.575113  0.722936  21493.92
#
# [568630 rows x 30 columns]

# %%
print (Y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 568625    1
# 568626    1
# 568627    1
# 568628    1
# 568629    1
# Name: Class, Length: 568630, dtype: int64

# %% [markdown]
# Split Data into train and test set

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size =0.2, stratify =Y, random_state = 2 )

# %%
print (X.shape,X_train.shape, X_test.shape)
# Out:
# (568630, 30) (454904, 30) (113726, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


model = LogisticRegression(max_iter=2000)
model.fit(X_train_scaled, Y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %% [markdown]
# Model Evaulation
#
# Accuracy Score

# %%
x_train_prediction = model.predict(X_train_scaled)
training_data_accuarcy = accuracy_score(x_train_prediction, Y_train)

# %%
print('Accuarcy on Training:', training_data_accuarcy)
# Out:
# Accuarcy on Training: 0.9984040588783567

# %%
x_test_prediction = model.predict(X_test_scaled)
test_data_accuarcy = accuracy_score(x_test_prediction, Y_test)

# %%
print('Accuracy on Test Data: ',test_data_accuarcy)
# Out:
# Accuracy on Test Data:  0.9982589733218438
